# %% [markdown]
# ## 区ごとに分けて学習させる
# ## CVあり

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
pd.options.display.max_columns = 100
import japanize_matplotlib

from time import time
import seaborn as sns
import pandas_profiling as pdp
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

from IPython.display import display
import gc

import lightgbm as lgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold

# %%
train=pd.read_feather('../data/train_feat3.ftr')
test=pd.read_feather('../data/test_feat3.ftr')

# %%
drop_cols=['rent/S_mean', 'rent/S_max',
       'rent/S_min', 'rent/S_median', 'rent/S_std', 'rent_mean', 'rent_max',
       'rent_min', 'rent_median', 'rent_std']
train.drop(drop_cols,axis=1,inplace=True)
test.drop(drop_cols,axis=1,inplace=True)

train.drop(['id'],axis=1,inplace=True)
test.drop(['id','level_0','index'],axis=1,inplace=True)

train['rent']=np.log(train['rent'])

# %%
def build_x_y_data(df,address_type):
    y_data=df[df['address_city']==address_type]['rent']
    X_data=df[df['address_city']==address_type].drop(['rent'],axis=1)
    return X_data,y_data

# %%
params = {
    'objective':'regression', 
    'max_bin' : 200,
    'n_estimators' : 20000,
    'learning_rate': 0.01,
    'min_data_in_leaf' : 50,
    'num_leaves' : 100,
    'sparse_threshold' : 1.0,
    'device' : 'cpu',
    'save_binary': True,
    'seed' : 42,
    'feature_fraction_seed': 42,
    'bagging_seed' : 42,
    'drop_seed' : 42,
    'data_random_seed' : 42,
    'objective' : 'regression',
    'boosting_type' : 'gbdt',
    'verbose' : 0,
    'metric' : 'RMSE',
    'is_unbalance' : True,
    'boost_from_average' : False,
}

# %%
def rmse(y_true,y_pred):
    return np.sqrt(mean_squared_error(y_true,y_pred))

# %%
def train_and_predict_for_address_type(address_type,submission,splits=5,random_state=0): 

    X_train,Y_train = build_x_y_data(train,address_type)
    X_test,_ = build_x_y_data(test,address_type)
    folds = KFold(n_splits=splits,shuffle=True)

    categorical_features=list(X_train.columns[X_train.dtypes=='category'])

    aucs = list()
    feature_importances = pd.DataFrame()
    feature_importances['feature'] = X_train.columns

    training_start_time = time()

    cv={}
    y_preds = np.zeros(X_test.shape[0])

    for fold_n, (trn_idx, val_idx) in enumerate(folds.split(X_train,Y_train)):
        cv_fold_start_time = time()
        print ('** Training fold {}'.format(fold_n + 1))
        X_trn, X_val = X_train.iloc[trn_idx], X_train.iloc[val_idx]
        y_trn, y_val = Y_train.iloc[trn_idx], Y_train.iloc[val_idx]
        eval_set  = [(X_trn,y_trn), (X_val, y_val)]

        reg = lgb.LGBMRegressor(**params)
        reg.fit(X_trn, y_trn,
                eval_set=eval_set, 
                eval_metric="rmse",
                early_stopping_rounds=100,
                categorical_feature = categorical_features,
                verbose= 500)

        del X_trn, y_trn

        val_pred=reg.predict(X_val)
        feature_importances['fold_{}'.format(fold_n + 1)] = reg.feature_importances_

        y_preds+=reg.predict(X_test)/splits
        del reg, X_val
        val_rmse=rmse(np.exp(y_val),np.exp(val_pred))
        print('RMSE accuracy: {}'.format(val_rmse))
        cv[fold_n+1]=val_rmse
        del val_pred,y_val,val_rmse

        gc.collect()

        cv_fold_end_time = time()
        print ('fold completed in {}s'.format(cv_fold_end_time - cv_fold_start_time))
    cv=pd.DataFrame(cv,index=['cv',])
    print('CV RMSE:{}'.format(cv.mean(axis=1)))
    tmp=test.copy()
    submission.loc[tmp['address_city']==address_type,1]=np.exp(y_preds)
    
    return cv.mean(axis=1)[0]

# %%
sub=pd.read_csv('../../../input/sample_submit.csv',header=None)
submission = sub.copy()
FOLD=5

cv_scores = {}
for address_type in set(train['address_city'].unique()):
    cv_score = train_and_predict_for_address_type(
        address_type, submission, splits=FOLD)
    cv_scores[address_type] = cv_score
# Out:
# ** Training fold 1
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.102877	valid_1's rmse: 0.120602
# [1000]	training's rmse: 0.0447829	valid_1's rmse: 0.0894327
# [1500]	training's rmse: 0.0330722	valid_1's rmse: 0.087241
# [2000]	training's rmse: 0.0259252	valid_1's rmse: 0.08603
# [2500]	training's rmse: 0.0210572	valid_1's rmse: 0.0852418
# [3000]	training's rmse: 0.0175855	valid_1's rmse: 0.0847711
# [3500]	training's rmse: 0.0150131	valid_1's rmse: 0.0844784
# [4000]	training's rmse: 0.0129072	valid_1's rmse: 0.0842155
# [4500]	training's rmse: 0.0113667	valid_1's rmse: 0.0840708
# [5000]	training's rmse: 0.0100435	valid_1's rmse: 0.0839146
# [5500]	training's rmse: 0.00889222	valid_1's rmse: 0.0838278
# [6000]	training's rmse: 0.00789184	valid_1's rmse: 0.0837742
# [6500]	training's rmse: 0.006982	valid_1's rmse: 0.0837497
# Early stopping, best iteration is:
# [6501]	training's rmse: 0.00697941	valid_1's rmse: 0.0837484
# RMSE accuracy: 11091.94940450327
# fold completed in 12.814441919326782s
# ** Training fold 2
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.102139	valid_1's rmse: 0.124102
# [1000]	training's rmse: 0.0445028	valid_1's rmse: 0.0913035
# [1500]	training's rmse: 0.0327783	valid_1's rmse: 0.0900338
# [2000]	training's rmse: 0.0255479	valid_1's rmse: 0.0894217
# [2500]	training's rmse: 0.0206606	valid_1's rmse: 0.0892522
# Early stopping, best iteration is:
# [2500]	training's rmse: 0.0206606	valid_1's rmse: 0.0892522
# RMSE accuracy: 12811.66594425018
# fold completed in 5.214425086975098s
# ** Training fold 3
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.103138	valid_1's rmse: 0.11458
# [1000]	training's rmse: 0.044862	valid_1's rmse: 0.0870653
# [1500]	training's rmse: 0.0328149	valid_1's rmse: 0.0866878
# Early stopping, best iteration is:
# [1516]	training's rmse: 0.0325439	valid_1's rmse: 0.0866694
# RMSE accuracy: 10979.032703037215
# fold completed in 3.5754010677337646s
# ** Training fold 4
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.101908	valid_1's rmse: 0.125011
# [1000]	training's rmse: 0.04371	valid_1's rmse: 0.094193
# [1500]	training's rmse: 0.0321588	valid_1's rmse: 0.093331
# [2000]	training's rmse: 0.0250142	valid_1's rmse: 0.0929279
# [2500]	training's rmse: 0.0195539	valid_1's rmse: 0.092774
# [3000]	training's rmse: 0.0157122	valid_1's rmse: 0.0925552
# [3500]	training's rmse: 0.0130719	valid_1's rmse: 0.0924118
# [4000]	training's rmse: 0.0110574	valid_1's rmse: 0.0923519
# Early stopping, best iteration is:
# [3939]	training's rmse: 0.0112833	valid_1's rmse: 0.0923443
# RMSE accuracy: 12692.08777319142
# fold completed in 9.2307448387146s
# ** Training fold 5
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.10223	valid_1's rmse: 0.126131
# [1000]	training's rmse: 0.0432559	valid_1's rmse: 0.0962845
# [1500]	training's rmse: 0.0308333	valid_1's rmse: 0.0952256
# Early stopping, best iteration is:
# [1843]	training's rmse: 0.0250464	valid_1's rmse: 0.0949432
# RMSE accuracy: 21890.518206497574
# fold completed in 5.079081058502197s
# CV RMSE:cv    13893.050806
# dtype: float64
# ** Training fold 1
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.108524	valid_1's rmse: 0.118313
# [1000]	training's rmse: 0.0515534	valid_1's rmse: 0.0858481
# [1500]	training's rmse: 0.0397173	valid_1's rmse: 0.082382
# [2000]	training's rmse: 0.0322687	valid_1's rmse: 0.0807581
# [2500]	training's rmse: 0.0270265	valid_1's rmse: 0.0801119
# Early stopping, best iteration is:
# [2890]	training's rmse: 0.023994	valid_1's rmse: 0.0796566
# RMSE accuracy: 20173.398769515978
# fold completed in 5.518312931060791s
# ** Training fold 2
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.108144	valid_1's rmse: 0.130449
# [1000]	training's rmse: 0.0507624	valid_1's rmse: 0.0854323
# [1500]	training's rmse: 0.0384801	valid_1's rmse: 0.0832179
# [2000]	training's rmse: 0.030803	valid_1's rmse: 0.0822415
# Early stopping, best iteration is:
# [2066]	training's rmse: 0.0300041	valid_1's rmse: 0.082172
# RMSE accuracy: 17267.448017946826
# fold completed in 3.573755979537964s
# ** Training fold 3
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.108091	valid_1's rmse: 0.120164
# [1000]	training's rmse: 0.0506136	valid_1's rmse: 0.0810274
# [1500]	training's rmse: 0.0388676	valid_1's rmse: 0.0786737
# [2000]	training's rmse: 0.031662	valid_1's rmse: 0.0777676
# [2500]	training's rmse: 0.0266844	valid_1's rmse: 0.077204
# [3000]	training's rmse: 0.0228183	valid_1's rmse: 0.0765566
# [3500]	training's rmse: 0.0199723	valid_1's rmse: 0.075983
# [4000]	training's rmse: 0.0176	valid_1's rmse: 0.0756161
# Early stopping, best iteration is:
# [4025]	training's rmse: 0.017488	valid_1's rmse: 0.0755931
# RMSE accuracy: 21151.94382004204
# fold completed in 6.713374137878418s
# ** Training fold 4
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.108393	valid_1's rmse: 0.111756
# [1000]	training's rmse: 0.0518394	valid_1's rmse: 0.0791049
# [1500]	training's rmse: 0.040318	valid_1's rmse: 0.0756522
# [2000]	training's rmse: 0.0327526	valid_1's rmse: 0.0735087
# [2500]	training's rmse: 0.0275422	valid_1's rmse: 0.0721133
# [3000]	training's rmse: 0.0236101	valid_1's rmse: 0.0708493
# [3500]	training's rmse: 0.0204922	valid_1's rmse: 0.0701162
# [4000]	training's rmse: 0.0178542	valid_1's rmse: 0.0696123
# [4500]	training's rmse: 0.0157889	valid_1's rmse: 0.0691612
# [5000]	training's rmse: 0.014105	valid_1's rmse: 0.0688057
# [5500]	training's rmse: 0.0127427	valid_1's rmse: 0.0685348
# [6000]	training's rmse: 0.0115981	valid_1's rmse: 0.0683053
# [6500]	training's rmse: 0.0105638	valid_1's rmse: 0.0681075
# [7000]	training's rmse: 0.00970726	valid_1's rmse: 0.0679579
# [7500]	training's rmse: 0.00892776	valid_1's rmse: 0.0678725
# Early stopping, best iteration is:
# [7628]	training's rmse: 0.00874988	valid_1's rmse: 0.0678553
# RMSE accuracy: 14738.522666673218
# fold completed in 10.380325078964233s
# ** Training fold 5
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.106073	valid_1's rmse: 0.129545
# [1000]	training's rmse: 0.0475556	valid_1's rmse: 0.0908868
# [1500]	training's rmse: 0.0360058	valid_1's rmse: 0.0885737
# [2000]	training's rmse: 0.0288048	valid_1's rmse: 0.0869703
# [2500]	training's rmse: 0.0240538	valid_1's rmse: 0.0864752
# [3000]	training's rmse: 0.0205496	valid_1's rmse: 0.086064
# [3500]	training's rmse: 0.0180604	valid_1's rmse: 0.0858589
# [4000]	training's rmse: 0.0160319	valid_1's rmse: 0.0856749
# [4500]	training's rmse: 0.014416	valid_1's rmse: 0.0855531
# Early stopping, best iteration is:
# [4644]	training's rmse: 0.0139957	valid_1's rmse: 0.0855223
# RMSE accuracy: 15809.234952810428
# fold completed in 5.822843790054321s
# CV RMSE:cv    17828.109645
# dtype: float64
# ** Training fold 1
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.107134	valid_1's rmse: 0.111041
# [1000]	training's rmse: 0.0519535	valid_1's rmse: 0.0853602
# [1500]	training's rmse: 0.040362	valid_1's rmse: 0.083726
# Early stopping, best iteration is:
# [1620]	training's rmse: 0.0382727	valid_1's rmse: 0.0835748
# RMSE accuracy: 7745.151357438451
# fold completed in 2.2428300380706787s
# ** Training fold 2
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.106725	valid_1's rmse: 0.120518
# [1000]	training's rmse: 0.0522683	valid_1's rmse: 0.0825478
# [1500]	training's rmse: 0.0401054	valid_1's rmse: 0.081333
# Early stopping, best iteration is:
# [1623]	training's rmse: 0.0378059	valid_1's rmse: 0.0811238
# RMSE accuracy: 10105.247110666254
# fold completed in 2.3322839736938477s
# ** Training fold 3
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.104219	valid_1's rmse: 0.13702
# [1000]	training's rmse: 0.0502783	valid_1's rmse: 0.102419
# [1500]	training's rmse: 0.0389187	valid_1's rmse: 0.0990644
# [2000]	training's rmse: 0.0315666	valid_1's rmse: 0.0973424
# [2500]	training's rmse: 0.026341	valid_1's rmse: 0.0960482
# [3000]	training's rmse: 0.0224159	valid_1's rmse: 0.0953641
# [3500]	training's rmse: 0.0194178	valid_1's rmse: 0.0949625
# [4000]	training's rmse: 0.0170184	valid_1's rmse: 0.0948009
# [4500]	training's rmse: 0.0151504	valid_1's rmse: 0.0946563
# [5000]	training's rmse: 0.0135823	valid_1's rmse: 0.0945522
# [5500]	training's rmse: 0.0122359	valid_1's rmse: 0.0944557
# Early stopping, best iteration is:
# [5530]	training's rmse: 0.01216	valid_1's rmse: 0.0944487
# RMSE accuracy: 11969.10582829343
# fold completed in 6.533425807952881s
# ** Training fold 4
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.103574	valid_1's rmse: 0.132442
# [1000]	training's rmse: 0.0485644	valid_1's rmse: 0.10049
# [1500]	training's rmse: 0.0373443	valid_1's rmse: 0.0985862
# [2000]	training's rmse: 0.0299032	valid_1's rmse: 0.0975164
# [2500]	training's rmse: 0.024692	valid_1's rmse: 0.0964186
# [3000]	training's rmse: 0.0208346	valid_1's rmse: 0.0958988
# [3500]	training's rmse: 0.0178397	valid_1's rmse: 0.0953834
# [4000]	training's rmse: 0.0155456	valid_1's rmse: 0.0951212
# [4500]	training's rmse: 0.0135829	valid_1's rmse: 0.0947429
# [5000]	training's rmse: 0.0120693	valid_1's rmse: 0.0943319
# [5500]	training's rmse: 0.0107819	valid_1's rmse: 0.0940612
# [6000]	training's rmse: 0.00972175	valid_1's rmse: 0.0938277
# [6500]	training's rmse: 0.00879103	valid_1's rmse: 0.0937493
# [7000]	training's rmse: 0.00806783	valid_1's rmse: 0.0936544
# [7500]	training's rmse: 0.00746489	valid_1's rmse: 0.0935581
# [8000]	training's rmse: 0.00694446	valid_1's rmse: 0.0934447
# [8500]	training's rmse: 0.00650414	valid_1's rmse: 0.0933134
# [9000]	training's rmse: 0.00610361	valid_1's rmse: 0.0932301
# [9500]	training's rmse: 0.00575812	valid_1's rmse: 0.0931407
# [10000]	training's rmse: 0.00545833	valid_1's rmse: 0.0930601
# [10500]	training's rmse: 0.00519712	valid_1's rmse: 0.0929757
# [11000]	training's rmse: 0.00495986	valid_1's rmse: 0.0929055
# [11500]	training's rmse: 0.00474675	valid_1's rmse: 0.092836
# [12000]	training's rmse: 0.00456161	valid_1's rmse: 0.0927795
# [12500]	training's rmse: 0.00439578	valid_1's rmse: 0.0927248
# [13000]	training's rmse: 0.00424311	valid_1's rmse: 0.0926701
# [13500]	training's rmse: 0.00410984	valid_1's rmse: 0.0926196
# [14000]	training's rmse: 0.00398853	valid_1's rmse: 0.0925719
# [14500]	training's rmse: 0.00387814	valid_1's rmse: 0.0925317
# [15000]	training's rmse: 0.00378044	valid_1's rmse: 0.0925055
# [15500]	training's rmse: 0.00368706	valid_1's rmse: 0.0924723
# [16000]	training's rmse: 0.00360013	valid_1's rmse: 0.0924563
# [16500]	training's rmse: 0.00352062	valid_1's rmse: 0.0924363
# [17000]	training's rmse: 0.0034478	valid_1's rmse: 0.0924038
# [17500]	training's rmse: 0.00337973	valid_1's rmse: 0.0923757
# [18000]	training's rmse: 0.0033185	valid_1's rmse: 0.0923462
# [18500]	training's rmse: 0.00326322	valid_1's rmse: 0.0923276
# [19000]	training's rmse: 0.00321363	valid_1's rmse: 0.0923156
# [19500]	training's rmse: 0.00316677	valid_1's rmse: 0.0923023
# [20000]	training's rmse: 0.00312407	valid_1's rmse: 0.0922842
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 0.00312407	valid_1's rmse: 0.0922842
# RMSE accuracy: 12490.304912727494
# fold completed in 33.27818965911865s
# ** Training fold 5
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.108114	valid_1's rmse: 0.116497
# [1000]	training's rmse: 0.053197	valid_1's rmse: 0.083702
# [1500]	training's rmse: 0.0406273	valid_1's rmse: 0.0825996
# [2000]	training's rmse: 0.0327456	valid_1's rmse: 0.0819758
# Early stopping, best iteration is:
# [2147]	training's rmse: 0.0308939	valid_1's rmse: 0.0817529
# RMSE accuracy: 7653.5040356683385
# fold completed in 4.48900294303894s
# CV RMSE:cv    9992.662649
# dtype: float64
# ** Training fold 1
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.1093	valid_1's rmse: 0.127438
# [1000]	training's rmse: 0.0539823	valid_1's rmse: 0.103443
# [1500]	training's rmse: 0.0415962	valid_1's rmse: 0.0995316
# [2000]	training's rmse: 0.0333099	valid_1's rmse: 0.0982769
# [2500]	training's rmse: 0.0274664	valid_1's rmse: 0.0970776
# [3000]	training's rmse: 0.0229461	valid_1's rmse: 0.0961123
# [3500]	training's rmse: 0.0195597	valid_1's rmse: 0.0956409
# [4000]	training's rmse: 0.0168719	valid_1's rmse: 0.0951927
# [4500]	training's rmse: 0.0147008	valid_1's rmse: 0.0948856
# Early stopping, best iteration is:
# [4550]	training's rmse: 0.0145162	valid_1's rmse: 0.0948656
# RMSE accuracy: 10394.645987232387
# fold completed in 7.4710118770599365s
# ** Training fold 2
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.109297	valid_1's rmse: 0.140574
# [1000]	training's rmse: 0.0530701	valid_1's rmse: 0.102887
# [1500]	training's rmse: 0.040032	valid_1's rmse: 0.101039
# Early stopping, best iteration is:
# [1673]	training's rmse: 0.036688	valid_1's rmse: 0.100723
# RMSE accuracy: 12889.648729697645
# fold completed in 3.0486409664154053s
# ** Training fold 3
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.109367	valid_1's rmse: 0.125328
# [1000]	training's rmse: 0.0535307	valid_1's rmse: 0.0950989
# [1500]	training's rmse: 0.04075	valid_1's rmse: 0.0931053
# [2000]	training's rmse: 0.0323369	valid_1's rmse: 0.0916889
# [2500]	training's rmse: 0.0265768	valid_1's rmse: 0.0910251
# Early stopping, best iteration is:
# [2487]	training's rmse: 0.0267156	valid_1's rmse: 0.0910122
# RMSE accuracy: 9603.973800770429
# fold completed in 4.254056930541992s
# ** Training fold 4
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.107894	valid_1's rmse: 0.130556
# [1000]	training's rmse: 0.0516427	valid_1's rmse: 0.0974863
# [1500]	training's rmse: 0.0388173	valid_1's rmse: 0.0958527
# [2000]	training's rmse: 0.0303669	valid_1's rmse: 0.0949484
# Early stopping, best iteration is:
# [2085]	training's rmse: 0.0292184	valid_1's rmse: 0.094868
# RMSE accuracy: 16658.205254195054
# fold completed in 3.7368788719177246s
# ** Training fold 5
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.111068	valid_1's rmse: 0.117297
# [1000]	training's rmse: 0.0549819	valid_1's rmse: 0.0872558
# [1500]	training's rmse: 0.0414757	valid_1's rmse: 0.0858371
# [2000]	training's rmse: 0.0326675	valid_1's rmse: 0.0852034
# [2500]	training's rmse: 0.0263718	valid_1's rmse: 0.0848037
# [3000]	training's rmse: 0.0218147	valid_1's rmse: 0.0842391
# [3500]	training's rmse: 0.0183351	valid_1's rmse: 0.0840702
# Early stopping, best iteration is:
# [3541]	training's rmse: 0.0180765	valid_1's rmse: 0.0840307
# RMSE accuracy: 9681.13601023924
# fold completed in 5.901671886444092s
# CV RMSE:cv    11845.521956
# dtype: float64
# ** Training fold 1
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.145064	valid_1's rmse: 0.131383
# [1000]	training's rmse: 0.0820812	valid_1's rmse: 0.0934114
# [1500]	training's rmse: 0.0626548	valid_1's rmse: 0.0848787
# [2000]	training's rmse: 0.0501969	valid_1's rmse: 0.0807489
# [2500]	training's rmse: 0.0406741	valid_1's rmse: 0.0789773
# Early stopping, best iteration is:
# [2838]	training's rmse: 0.0359809	valid_1's rmse: 0.0783812
# RMSE accuracy: 26852.86370121139
# fold completed in 3.5589728355407715s
# ** Training fold 2
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.141554	valid_1's rmse: 0.206213
# [1000]	training's rmse: 0.0802919	valid_1's rmse: 0.160289
# [1500]	training's rmse: 0.0635859	valid_1's rmse: 0.149789
# [2000]	training's rmse: 0.0527391	valid_1's rmse: 0.144724
# [2500]	training's rmse: 0.0443338	valid_1's rmse: 0.141164
# [3000]	training's rmse: 0.0382355	valid_1's rmse: 0.138942
# [3500]	training's rmse: 0.0335543	valid_1's rmse: 0.137678
# [4000]	training's rmse: 0.0299007	valid_1's rmse: 0.136923
# Early stopping, best iteration is:
# [3917]	training's rmse: 0.0305049	valid_1's rmse: 0.136833
# RMSE accuracy: 61978.48836674689
# fold completed in 4.444467782974243s
# ** Training fold 3
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.145291	valid_1's rmse: 0.143002
# [1000]	training's rmse: 0.0831329	valid_1's rmse: 0.103916
# [1500]	training's rmse: 0.0633719	valid_1's rmse: 0.0953062
# [2000]	training's rmse: 0.050188	valid_1's rmse: 0.0902798
# [2500]	training's rmse: 0.0415711	valid_1's rmse: 0.0881864
# Early stopping, best iteration is:
# [2610]	training's rmse: 0.0401005	valid_1's rmse: 0.087965
# RMSE accuracy: 24592.716228348345
# fold completed in 3.0662059783935547s
# ** Training fold 4
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.140937	valid_1's rmse: 0.142178
# [1000]	training's rmse: 0.0802097	valid_1's rmse: 0.108526
# [1500]	training's rmse: 0.0619495	valid_1's rmse: 0.100907
# [2000]	training's rmse: 0.0511914	valid_1's rmse: 0.096477
# [2500]	training's rmse: 0.0430372	valid_1's rmse: 0.0943158
# [3000]	training's rmse: 0.0362037	valid_1's rmse: 0.0919893
# [3500]	training's rmse: 0.031024	valid_1's rmse: 0.0911388
# [4000]	training's rmse: 0.0272814	valid_1's rmse: 0.0902279
# [4500]	training's rmse: 0.0241739	valid_1's rmse: 0.0894067
# [5000]	training's rmse: 0.021618	valid_1's rmse: 0.088779
# [5500]	training's rmse: 0.0195039	valid_1's rmse: 0.0883425
# Early stopping, best iteration is:
# [5580]	training's rmse: 0.0192084	valid_1's rmse: 0.0882441
# RMSE accuracy: 26408.43949164835
# fold completed in 6.139885663986206s
# ** Training fold 5
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.141873	valid_1's rmse: 0.179509
# [1000]	training's rmse: 0.0852161	valid_1's rmse: 0.124734
# [1500]	training's rmse: 0.0661614	valid_1's rmse: 0.112512
# [2000]	training's rmse: 0.0526494	valid_1's rmse: 0.106922
# [2500]	training's rmse: 0.0441365	valid_1's rmse: 0.104987
# [3000]	training's rmse: 0.036995	valid_1's rmse: 0.103784
# [3500]	training's rmse: 0.0320615	valid_1's rmse: 0.102819
# [4000]	training's rmse: 0.0282621	valid_1's rmse: 0.101863
# [4500]	training's rmse: 0.0251159	valid_1's rmse: 0.101241
# [5000]	training's rmse: 0.022502	valid_1's rmse: 0.100544
# [5500]	training's rmse: 0.0199771	valid_1's rmse: 0.0985175
# [6000]	training's rmse: 0.0180738	valid_1's rmse: 0.0976849
# [6500]	training's rmse: 0.0165848	valid_1's rmse: 0.0972423
# Early stopping, best iteration is:
# [6862]	training's rmse: 0.0156822	valid_1's rmse: 0.0970039
# RMSE accuracy: 43937.96482108561
# fold completed in 7.098074197769165s
# CV RMSE:cv    36754.094522
# dtype: float64
# ** Training fold 1
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.110967	valid_1's rmse: 0.121035
# [1000]	training's rmse: 0.0558782	valid_1's rmse: 0.0852735
# Early stopping, best iteration is:
# [1172]	training's rmse: 0.0508624	valid_1's rmse: 0.0847067
# RMSE accuracy: 9988.780169523328
# fold completed in 2.355452299118042s
# ** Training fold 2
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.112417	valid_1's rmse: 0.126275
# [1000]	training's rmse: 0.0578427	valid_1's rmse: 0.0846859
# Early stopping, best iteration is:
# [1268]	training's rmse: 0.0502888	valid_1's rmse: 0.0842856
# RMSE accuracy: 14243.678664817906
# fold completed in 2.429217576980591s
# ** Training fold 3
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.111432	valid_1's rmse: 0.113252
# [1000]	training's rmse: 0.0575002	valid_1's rmse: 0.0813357
# [1500]	training's rmse: 0.0455604	valid_1's rmse: 0.078679
# [2000]	training's rmse: 0.0374357	valid_1's rmse: 0.0774437
# [2500]	training's rmse: 0.0314346	valid_1's rmse: 0.0765269
# Early stopping, best iteration is:
# [2500]	training's rmse: 0.0314346	valid_1's rmse: 0.0765269
# RMSE accuracy: 10896.133390682104
# fold completed in 4.352947950363159s
# ** Training fold 4
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.108468	valid_1's rmse: 0.132688
# [1000]	training's rmse: 0.0534014	valid_1's rmse: 0.108374
# [1500]	training's rmse: 0.041965	valid_1's rmse: 0.104193
# [2000]	training's rmse: 0.0347947	valid_1's rmse: 0.101767
# [2500]	training's rmse: 0.0297389	valid_1's rmse: 0.100275
# [3000]	training's rmse: 0.0260495	valid_1's rmse: 0.0994879
# [3500]	training's rmse: 0.0231862	valid_1's rmse: 0.098852
# [4000]	training's rmse: 0.0208626	valid_1's rmse: 0.0981457
# [4500]	training's rmse: 0.0189919	valid_1's rmse: 0.0974053
# [5000]	training's rmse: 0.0173083	valid_1's rmse: 0.0969029
# [5500]	training's rmse: 0.0158944	valid_1's rmse: 0.0964809
# [6000]	training's rmse: 0.0146841	valid_1's rmse: 0.0961618
# [6500]	training's rmse: 0.0135951	valid_1's rmse: 0.095848
# [7000]	training's rmse: 0.0126048	valid_1's rmse: 0.0954696
# [7500]	training's rmse: 0.0117568	valid_1's rmse: 0.0951392
# [8000]	training's rmse: 0.0109777	valid_1's rmse: 0.0948492
# [8500]	training's rmse: 0.0102773	valid_1's rmse: 0.0946
# [9000]	training's rmse: 0.0096552	valid_1's rmse: 0.0944036
# [9500]	training's rmse: 0.00910294	valid_1's rmse: 0.0942114
# [10000]	training's rmse: 0.00857712	valid_1's rmse: 0.0940542
# [10500]	training's rmse: 0.00809478	valid_1's rmse: 0.0938345
# [11000]	training's rmse: 0.0076513	valid_1's rmse: 0.0936278
# [11500]	training's rmse: 0.00723778	valid_1's rmse: 0.0934764
# [12000]	training's rmse: 0.00684979	valid_1's rmse: 0.0933235
# [12500]	training's rmse: 0.00648288	valid_1's rmse: 0.0931663
# [13000]	training's rmse: 0.00615177	valid_1's rmse: 0.093043
# [13500]	training's rmse: 0.00584479	valid_1's rmse: 0.0929147
# [14000]	training's rmse: 0.00555562	valid_1's rmse: 0.0927908
# [14500]	training's rmse: 0.00528311	valid_1's rmse: 0.0926572
# [15000]	training's rmse: 0.00503272	valid_1's rmse: 0.0925613
# [15500]	training's rmse: 0.00480708	valid_1's rmse: 0.0924681
# [16000]	training's rmse: 0.00460088	valid_1's rmse: 0.092377
# [16500]	training's rmse: 0.00440215	valid_1's rmse: 0.092288
# [17000]	training's rmse: 0.00420011	valid_1's rmse: 0.0921907
# [17500]	training's rmse: 0.00401476	valid_1's rmse: 0.0921102
# [18000]	training's rmse: 0.00384896	valid_1's rmse: 0.0920441
# [18500]	training's rmse: 0.00369292	valid_1's rmse: 0.0919721
# [19000]	training's rmse: 0.00355529	valid_1's rmse: 0.0919076
# [19500]	training's rmse: 0.0034139	valid_1's rmse: 0.0918443
# [20000]	training's rmse: 0.00328035	valid_1's rmse: 0.0917923
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 0.00328035	valid_1's rmse: 0.0917923
# RMSE accuracy: 18787.8038139456
# fold completed in 29.900532960891724s
# ** Training fold 5
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.109056	valid_1's rmse: 0.145673
# [1000]	training's rmse: 0.0546902	valid_1's rmse: 0.113581
# [1500]	training's rmse: 0.0426659	valid_1's rmse: 0.108696
# [2000]	training's rmse: 0.0351341	valid_1's rmse: 0.106243
# [2500]	training's rmse: 0.0298196	valid_1's rmse: 0.104403
# [3000]	training's rmse: 0.0261367	valid_1's rmse: 0.102897
# [3500]	training's rmse: 0.0234148	valid_1's rmse: 0.101427
# [4000]	training's rmse: 0.0212132	valid_1's rmse: 0.100108
# [4500]	training's rmse: 0.0194363	valid_1's rmse: 0.0989293
# [5000]	training's rmse: 0.0179	valid_1's rmse: 0.0979506
# [5500]	training's rmse: 0.0166231	valid_1's rmse: 0.0970809
# [6000]	training's rmse: 0.0154754	valid_1's rmse: 0.0962027
# [6500]	training's rmse: 0.0144609	valid_1's rmse: 0.0954754
# [7000]	training's rmse: 0.0135099	valid_1's rmse: 0.0947553
# [7500]	training's rmse: 0.0126629	valid_1's rmse: 0.094247
# [8000]	training's rmse: 0.0119216	valid_1's rmse: 0.0937395
# [8500]	training's rmse: 0.0112294	valid_1's rmse: 0.0932864
# [9000]	training's rmse: 0.0105597	valid_1's rmse: 0.092809
# [9500]	training's rmse: 0.00996555	valid_1's rmse: 0.0924654
# [10000]	training's rmse: 0.00940986	valid_1's rmse: 0.0921939
# [10500]	training's rmse: 0.00889164	valid_1's rmse: 0.0918719
# [11000]	training's rmse: 0.00841602	valid_1's rmse: 0.0915941
# [11500]	training's rmse: 0.0079689	valid_1's rmse: 0.0913371
# [12000]	training's rmse: 0.00754426	valid_1's rmse: 0.0911276
# [12500]	training's rmse: 0.00714482	valid_1's rmse: 0.0909567
# [13000]	training's rmse: 0.00678276	valid_1's rmse: 0.0907561
# [13500]	training's rmse: 0.00644229	valid_1's rmse: 0.0905885
# [14000]	training's rmse: 0.00611925	valid_1's rmse: 0.0904091
# [14500]	training's rmse: 0.00582043	valid_1's rmse: 0.0902355
# [15000]	training's rmse: 0.0055329	valid_1's rmse: 0.0900623
# [15500]	training's rmse: 0.00526237	valid_1's rmse: 0.0899117
# [16000]	training's rmse: 0.00500407	valid_1's rmse: 0.0897725
# [16500]	training's rmse: 0.0047679	valid_1's rmse: 0.0896364
# [17000]	training's rmse: 0.00453984	valid_1's rmse: 0.0895132
# [17500]	training's rmse: 0.00432308	valid_1's rmse: 0.0894154
# [18000]	training's rmse: 0.00412084	valid_1's rmse: 0.0893331
# [18500]	training's rmse: 0.00392596	valid_1's rmse: 0.0892527
# [19000]	training's rmse: 0.00374294	valid_1's rmse: 0.0891659
# [19500]	training's rmse: 0.00357158	valid_1's rmse: 0.0890753
# [20000]	training's rmse: 0.00340974	valid_1's rmse: 0.088993
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 0.00340974	valid_1's rmse: 0.088993
# RMSE accuracy: 20385.944023220607
# fold completed in 30.49404215812683s
# CV RMSE:cv    14860.468012
# dtype: float64
# ** Training fold 1
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.110677	valid_1's rmse: 0.133655
# [1000]	training's rmse: 0.0540463	valid_1's rmse: 0.108177
# [1500]	training's rmse: 0.0417909	valid_1's rmse: 0.105888
# [2000]	training's rmse: 0.0337373	valid_1's rmse: 0.104505
# [2500]	training's rmse: 0.0276366	valid_1's rmse: 0.103742
# [3000]	training's rmse: 0.0231954	valid_1's rmse: 0.103278
# Early stopping, best iteration is:
# [3294]	training's rmse: 0.0211146	valid_1's rmse: 0.10308
# RMSE accuracy: 33050.89768497348
# fold completed in 6.638159990310669s
# ** Training fold 2
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.115186	valid_1's rmse: 0.117888
# [1000]	training's rmse: 0.0587128	valid_1's rmse: 0.0910635
# Early stopping, best iteration is:
# [1131]	training's rmse: 0.0544104	valid_1's rmse: 0.0908801
# RMSE accuracy: 17285.277626500007
# fold completed in 2.4583537578582764s
# ** Training fold 3
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.112646	valid_1's rmse: 0.129919
# [1000]	training's rmse: 0.0557647	valid_1's rmse: 0.08727
# [1500]	training's rmse: 0.0443787	valid_1's rmse: 0.0853433
# [2000]	training's rmse: 0.0367464	valid_1's rmse: 0.0847752
# Early stopping, best iteration is:
# [2082]	training's rmse: 0.0357457	valid_1's rmse: 0.0847049
# RMSE accuracy: 19624.903215937014
# fold completed in 4.175442218780518s
# ** Training fold 4
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.113706	valid_1's rmse: 0.133385
# [1000]	training's rmse: 0.0583584	valid_1's rmse: 0.0977707
# [1500]	training's rmse: 0.045205	valid_1's rmse: 0.0960164
# [2000]	training's rmse: 0.0368065	valid_1's rmse: 0.0950797
# [2500]	training's rmse: 0.0309189	valid_1's rmse: 0.0944911
# [3000]	training's rmse: 0.0264646	valid_1's rmse: 0.0943204
# Early stopping, best iteration is:
# [2909]	training's rmse: 0.0271772	valid_1's rmse: 0.0942876
# RMSE accuracy: 13242.207248264505
# fold completed in 6.3168861865997314s
# ** Training fold 5
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.112116	valid_1's rmse: 0.145647
# [1000]	training's rmse: 0.0550138	valid_1's rmse: 0.117857
# [1500]	training's rmse: 0.0412353	valid_1's rmse: 0.117254
# Early stopping, best iteration is:
# [1508]	training's rmse: 0.0410711	valid_1's rmse: 0.117232
# RMSE accuracy: 25741.31467232034
# fold completed in 3.3483731746673584s
# CV RMSE:cv    21788.92009
# dtype: float64
# ** Training fold 1
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.101232	valid_1's rmse: 0.120657
# [1000]	training's rmse: 0.0441893	valid_1's rmse: 0.0820969
# [1500]	training's rmse: 0.0334862	valid_1's rmse: 0.0798302
# [2000]	training's rmse: 0.0267564	valid_1's rmse: 0.077929
# [2500]	training's rmse: 0.0219164	valid_1's rmse: 0.0765552
# [3000]	training's rmse: 0.018378	valid_1's rmse: 0.0754181
# [3500]	training's rmse: 0.0156545	valid_1's rmse: 0.0747739
# [4000]	training's rmse: 0.0135644	valid_1's rmse: 0.0742122
# [4500]	training's rmse: 0.0118328	valid_1's rmse: 0.0737875
# [5000]	training's rmse: 0.0103837	valid_1's rmse: 0.0734527
# [5500]	training's rmse: 0.00926523	valid_1's rmse: 0.0731731
# [6000]	training's rmse: 0.00832268	valid_1's rmse: 0.0729292
# [6500]	training's rmse: 0.00750064	valid_1's rmse: 0.0727552
# [7000]	training's rmse: 0.00678886	valid_1's rmse: 0.0725828
# [7500]	training's rmse: 0.00616191	valid_1's rmse: 0.0724234
# [8000]	training's rmse: 0.00557375	valid_1's rmse: 0.0722848
# [8500]	training's rmse: 0.00503471	valid_1's rmse: 0.0721752
# [9000]	training's rmse: 0.00457843	valid_1's rmse: 0.0720712
# Early stopping, best iteration is:
# [9352]	training's rmse: 0.00425503	valid_1's rmse: 0.0720303
# RMSE accuracy: 8687.530279972132
# fold completed in 15.417155742645264s
# ** Training fold 2
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.101682	valid_1's rmse: 0.117007
# Early stopping, best iteration is:
# [847]	training's rmse: 0.0484422	valid_1's rmse: 0.0863159
# RMSE accuracy: 10946.76273553312
# fold completed in 1.708113193511963s
# ** Training fold 3
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.102826	valid_1's rmse: 0.111823
# [1000]	training's rmse: 0.0454398	valid_1's rmse: 0.069318
# [1500]	training's rmse: 0.034518	valid_1's rmse: 0.0673824
# [2000]	training's rmse: 0.0271909	valid_1's rmse: 0.0663231
# Early stopping, best iteration is:
# [2217]	training's rmse: 0.0248234	valid_1's rmse: 0.0660598
# RMSE accuracy: 9223.816058899785
# fold completed in 4.0435950756073s
# ** Training fold 4
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.102278	valid_1's rmse: 0.118159
# [1000]	training's rmse: 0.0461476	valid_1's rmse: 0.0793442
# [1500]	training's rmse: 0.0345613	valid_1's rmse: 0.0759088
# [2000]	training's rmse: 0.0271928	valid_1's rmse: 0.0743289
# [2500]	training's rmse: 0.0218808	valid_1's rmse: 0.0733027
# [3000]	training's rmse: 0.0180168	valid_1's rmse: 0.0727507
# [3500]	training's rmse: 0.0151026	valid_1's rmse: 0.0724611
# Early stopping, best iteration is:
# [3784]	training's rmse: 0.0137454	valid_1's rmse: 0.0723091
# RMSE accuracy: 8982.587439877654
# fold completed in 6.233931064605713s
# ** Training fold 5
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.0999128	valid_1's rmse: 0.120964
# [1000]	training's rmse: 0.042927	valid_1's rmse: 0.0930113
# [1500]	training's rmse: 0.0318125	valid_1's rmse: 0.0915432
# [2000]	training's rmse: 0.0246863	valid_1's rmse: 0.0900395
# [2500]	training's rmse: 0.0199641	valid_1's rmse: 0.0889242
# [3000]	training's rmse: 0.0162108	valid_1's rmse: 0.0881169
# [3500]	training's rmse: 0.0134873	valid_1's rmse: 0.0878343
# Early stopping, best iteration is:
# [3712]	training's rmse: 0.0125084	valid_1's rmse: 0.0877265
# RMSE accuracy: 14261.669400308047
# fold completed in 6.368849754333496s
# CV RMSE:cv    10420.473183
# dtype: float64
# ** Training fold 1
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.107843	valid_1's rmse: 0.117656
# [1000]	training's rmse: 0.0557355	valid_1's rmse: 0.0824526
# [1500]	training's rmse: 0.046735	valid_1's rmse: 0.0814319
# Early stopping, best iteration is:
# [1759]	training's rmse: 0.0436676	valid_1's rmse: 0.0811238
# RMSE accuracy: 10828.765420484204
# fold completed in 4.4353532791137695s
# ** Training fold 2
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.108154	valid_1's rmse: 0.110351
# [1000]	training's rmse: 0.0551732	valid_1's rmse: 0.0807149
# [1500]	training's rmse: 0.0458084	valid_1's rmse: 0.0801812
# [2000]	training's rmse: 0.0399766	valid_1's rmse: 0.0797884
# Early stopping, best iteration is:
# [1926]	training's rmse: 0.0407041	valid_1's rmse: 0.0797357
# RMSE accuracy: 9120.945163504952
# fold completed in 4.914549112319946s
# ** Training fold 3
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.100125	valid_1's rmse: 0.14762
# [1000]	training's rmse: 0.0407546	valid_1's rmse: 0.119604
# [1500]	training's rmse: 0.0285979	valid_1's rmse: 0.118273
# [2000]	training's rmse: 0.021241	valid_1's rmse: 0.117586
# [2500]	training's rmse: 0.0163439	valid_1's rmse: 0.117364
# Early stopping, best iteration is:
# [2723]	training's rmse: 0.0147311	valid_1's rmse: 0.117227
# RMSE accuracy: 60062.535711385455
# fold completed in 7.0345470905303955s
# ** Training fold 4
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.106865	valid_1's rmse: 0.121163
# [1000]	training's rmse: 0.053877	valid_1's rmse: 0.088887
# [1500]	training's rmse: 0.0444889	valid_1's rmse: 0.0865693
# [2000]	training's rmse: 0.0390961	valid_1's rmse: 0.0857071
# [2500]	training's rmse: 0.0354961	valid_1's rmse: 0.0853066
# [3000]	training's rmse: 0.0327506	valid_1's rmse: 0.0848518
# [3500]	training's rmse: 0.0305836	valid_1's rmse: 0.0846741
# [4000]	training's rmse: 0.0287355	valid_1's rmse: 0.0844476
# [4500]	training's rmse: 0.027122	valid_1's rmse: 0.0842664
# [5000]	training's rmse: 0.0256911	valid_1's rmse: 0.0841161
# [5500]	training's rmse: 0.0243868	valid_1's rmse: 0.0840255
# [6000]	training's rmse: 0.0231758	valid_1's rmse: 0.083959
# Early stopping, best iteration is:
# [6102]	training's rmse: 0.0229291	valid_1's rmse: 0.0839418
# RMSE accuracy: 10121.327047321714
# fold completed in 14.874813079833984s
# ** Training fold 5
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.107841	valid_1's rmse: 0.117974
# [1000]	training's rmse: 0.0552761	valid_1's rmse: 0.0812576
# [1500]	training's rmse: 0.0459141	valid_1's rmse: 0.0801025
# [2000]	training's rmse: 0.0405656	valid_1's rmse: 0.0795373
# [2500]	training's rmse: 0.0364968	valid_1's rmse: 0.0789373
# Early stopping, best iteration is:
# [2829]	training's rmse: 0.0344285	valid_1's rmse: 0.0787571
# RMSE accuracy: 9265.341091650056
# fold completed in 7.155787229537964s
# CV RMSE:cv    19879.782887
# dtype: float64
# ** Training fold 1
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.122635	valid_1's rmse: 0.156601
# [1000]	training's rmse: 0.0643013	valid_1's rmse: 0.121902
# [1500]	training's rmse: 0.050029	valid_1's rmse: 0.117592
# [2000]	training's rmse: 0.0401108	valid_1's rmse: 0.114723
# [2500]	training's rmse: 0.0330965	valid_1's rmse: 0.113065
# [3000]	training's rmse: 0.027566	valid_1's rmse: 0.111761
# [3500]	training's rmse: 0.0232486	valid_1's rmse: 0.111086
# [4000]	training's rmse: 0.0195907	valid_1's rmse: 0.110776
# [4500]	training's rmse: 0.016739	valid_1's rmse: 0.110366
# [5000]	training's rmse: 0.0143698	valid_1's rmse: 0.11006
# [5500]	training's rmse: 0.0123782	valid_1's rmse: 0.109884
# Early stopping, best iteration is:
# [5564]	training's rmse: 0.012166	valid_1's rmse: 0.109836
# RMSE accuracy: 16412.731273823516
# fold completed in 8.16963005065918s
# ** Training fold 2
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.122449	valid_1's rmse: 0.121784
# [1000]	training's rmse: 0.064185	valid_1's rmse: 0.0968315
# [1500]	training's rmse: 0.0479487	valid_1's rmse: 0.0902894
# [2000]	training's rmse: 0.0376076	valid_1's rmse: 0.0869794
# [2500]	training's rmse: 0.0302119	valid_1's rmse: 0.0855211
# [3000]	training's rmse: 0.0244977	valid_1's rmse: 0.0848184
# [3500]	training's rmse: 0.020107	valid_1's rmse: 0.0845028
# [4000]	training's rmse: 0.0166373	valid_1's rmse: 0.0841549
# Early stopping, best iteration is:
# [3971]	training's rmse: 0.0168157	valid_1's rmse: 0.0841221
# RMSE accuracy: 11511.751227505129
# fold completed in 6.227676868438721s
# ** Training fold 3
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.119339	valid_1's rmse: 0.157829
# [1000]	training's rmse: 0.0613209	valid_1's rmse: 0.114577
# [1500]	training's rmse: 0.046619	valid_1's rmse: 0.110983
# [2000]	training's rmse: 0.0366851	valid_1's rmse: 0.109075
# [2500]	training's rmse: 0.0297984	valid_1's rmse: 0.108003
# [3000]	training's rmse: 0.0247493	valid_1's rmse: 0.107555
# Early stopping, best iteration is:
# [3222]	training's rmse: 0.0229336	valid_1's rmse: 0.107434
# RMSE accuracy: 26883.252973797164
# fold completed in 5.506393909454346s
# ** Training fold 4
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.126559	valid_1's rmse: 0.123779
# Early stopping, best iteration is:
# [831]	training's rmse: 0.0744542	valid_1's rmse: 0.0926011
# RMSE accuracy: 14668.328576341419
# fold completed in 1.8006322383880615s
# ** Training fold 5
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.121451	valid_1's rmse: 0.144493
# [1000]	training's rmse: 0.0641066	valid_1's rmse: 0.111334
# [1500]	training's rmse: 0.0487725	valid_1's rmse: 0.106811
# [2000]	training's rmse: 0.0388594	valid_1's rmse: 0.104334
# [2500]	training's rmse: 0.0317197	valid_1's rmse: 0.103339
# [3000]	training's rmse: 0.0265379	valid_1's rmse: 0.102071
# [3500]	training's rmse: 0.0226166	valid_1's rmse: 0.10139
# [4000]	training's rmse: 0.0194756	valid_1's rmse: 0.10091
# [4500]	training's rmse: 0.0168946	valid_1's rmse: 0.10036
# [5000]	training's rmse: 0.0147329	valid_1's rmse: 0.0998838
# Early stopping, best iteration is:
# [5133]	training's rmse: 0.0142445	valid_1's rmse: 0.099794
# RMSE accuracy: 16796.542427431206
# fold completed in 7.599906921386719s
# CV RMSE:cv    17254.521296
# dtype: float64
# ** Training fold 1
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.116538	valid_1's rmse: 0.126489
# [1000]	training's rmse: 0.0595332	valid_1's rmse: 0.0945095
# [1500]	training's rmse: 0.0464175	valid_1's rmse: 0.0918199
# [2000]	training's rmse: 0.0380442	valid_1's rmse: 0.0903927
# [2500]	training's rmse: 0.0320302	valid_1's rmse: 0.0898822
# Early stopping, best iteration is:
# [2642]	training's rmse: 0.0306443	valid_1's rmse: 0.0898248
# RMSE accuracy: 16217.76868084853
# fold completed in 4.618373870849609s
# ** Training fold 2
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.1111	valid_1's rmse: 0.156828
# [1000]	training's rmse: 0.0525987	valid_1's rmse: 0.12125
# [1500]	training's rmse: 0.0384307	valid_1's rmse: 0.116736
# [2000]	training's rmse: 0.0295392	valid_1's rmse: 0.114878
# [2500]	training's rmse: 0.0241086	valid_1's rmse: 0.113707
# [3000]	training's rmse: 0.0200036	valid_1's rmse: 0.112793
# Early stopping, best iteration is:
# [3224]	training's rmse: 0.01854	valid_1's rmse: 0.112592
# RMSE accuracy: 50742.710478906214
# fold completed in 5.595616102218628s
# ** Training fold 3
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.115676	valid_1's rmse: 0.139973
# [1000]	training's rmse: 0.0588481	valid_1's rmse: 0.102739
# [1500]	training's rmse: 0.046574	valid_1's rmse: 0.0995318
# [2000]	training's rmse: 0.0385311	valid_1's rmse: 0.0987943
# [2500]	training's rmse: 0.0327476	valid_1's rmse: 0.0981859
# Early stopping, best iteration is:
# [2604]	training's rmse: 0.0317735	valid_1's rmse: 0.0980807
# RMSE accuracy: 17758.51914916082
# fold completed in 4.785428285598755s
# ** Training fold 4
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.117455	valid_1's rmse: 0.127949
# [1000]	training's rmse: 0.0602599	valid_1's rmse: 0.100048
# [1500]	training's rmse: 0.0476352	valid_1's rmse: 0.0988947
# [2000]	training's rmse: 0.0390672	valid_1's rmse: 0.098294
# [2500]	training's rmse: 0.0328702	valid_1's rmse: 0.0978548
# Early stopping, best iteration is:
# [2493]	training's rmse: 0.0329388	valid_1's rmse: 0.0978395
# RMSE accuracy: 15541.410297310142
# fold completed in 4.688637971878052s
# ** Training fold 5
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.115387	valid_1's rmse: 0.133046
# [1000]	training's rmse: 0.0590475	valid_1's rmse: 0.105334
# [1500]	training's rmse: 0.0453824	valid_1's rmse: 0.101998
# [2000]	training's rmse: 0.036632	valid_1's rmse: 0.100643
# [2500]	training's rmse: 0.0307534	valid_1's rmse: 0.0999423
# [3000]	training's rmse: 0.0266586	valid_1's rmse: 0.0994776
# Early stopping, best iteration is:
# [3037]	training's rmse: 0.0263978	valid_1's rmse: 0.0994392
# RMSE accuracy: 13787.106855154878
# fold completed in 5.471319913864136s
# CV RMSE:cv    22809.503092
# dtype: float64
# ** Training fold 1
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.102062	valid_1's rmse: 0.116342
# [1000]	training's rmse: 0.0439522	valid_1's rmse: 0.0812762
# Early stopping, best iteration is:
# [1233]	training's rmse: 0.0372699	valid_1's rmse: 0.0809801
# RMSE accuracy: 10540.27029387187
# fold completed in 3.009248971939087s
# ** Training fold 2
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.100253	valid_1's rmse: 0.129032
# [1000]	training's rmse: 0.0430374	valid_1's rmse: 0.104235
# [1500]	training's rmse: 0.0307953	valid_1's rmse: 0.103178
# [2000]	training's rmse: 0.0230944	valid_1's rmse: 0.102498
# [2500]	training's rmse: 0.0178105	valid_1's rmse: 0.102083
# Early stopping, best iteration is:
# [2526]	training's rmse: 0.0175877	valid_1's rmse: 0.102057
# RMSE accuracy: 15218.878488190943
# fold completed in 5.3784260749816895s
# ** Training fold 3
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.101685	valid_1's rmse: 0.123753
# [1000]	training's rmse: 0.0443265	valid_1's rmse: 0.0905135
# Early stopping, best iteration is:
# [1136]	training's rmse: 0.0402941	valid_1's rmse: 0.0902564
# RMSE accuracy: 12342.782571430598
# fold completed in 2.8759350776672363s
# ** Training fold 4
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.10105	valid_1's rmse: 0.124041
# [1000]	training's rmse: 0.0429994	valid_1's rmse: 0.0975918
# [1500]	training's rmse: 0.0309665	valid_1's rmse: 0.0965448
# Early stopping, best iteration is:
# [1576]	training's rmse: 0.0295214	valid_1's rmse: 0.0964558
# RMSE accuracy: 9517.069492906423
# fold completed in 3.922607183456421s
# ** Training fold 5
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.10234	valid_1's rmse: 0.117686
# [1000]	training's rmse: 0.0452545	valid_1's rmse: 0.0847114
# [1500]	training's rmse: 0.0326694	valid_1's rmse: 0.0827669
# [2000]	training's rmse: 0.0246218	valid_1's rmse: 0.0819479
# [2500]	training's rmse: 0.0190372	valid_1's rmse: 0.081548
# Early stopping, best iteration is:
# [2878]	training's rmse: 0.0158834	valid_1's rmse: 0.0813832
# RMSE accuracy: 8690.902014675612
# fold completed in 6.370579242706299s
# CV RMSE:cv    11261.980572
# dtype: float64
# ** Training fold 1
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.0987552	valid_1's rmse: 0.113363
# [1000]	training's rmse: 0.0417335	valid_1's rmse: 0.0874948
# [1500]	training's rmse: 0.0305506	valid_1's rmse: 0.0859976
# [2000]	training's rmse: 0.0234106	valid_1's rmse: 0.0854372
# [2500]	training's rmse: 0.0185925	valid_1's rmse: 0.0851719
# Early stopping, best iteration is:
# [2872]	training's rmse: 0.0159583	valid_1's rmse: 0.0849019
# RMSE accuracy: 7862.7474848895845
# fold completed in 5.780627965927124s
# ** Training fold 2
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.0995982	valid_1's rmse: 0.125465
# [1000]	training's rmse: 0.0424303	valid_1's rmse: 0.088612
# [1500]	training's rmse: 0.030823	valid_1's rmse: 0.0865001
# Early stopping, best iteration is:
# [1886]	training's rmse: 0.0250683	valid_1's rmse: 0.0859662
# RMSE accuracy: 8427.591965483849
# fold completed in 4.003411054611206s
# ** Training fold 3
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.099572	valid_1's rmse: 0.11078
# [1000]	training's rmse: 0.0423634	valid_1's rmse: 0.0774347
# Early stopping, best iteration is:
# [1268]	training's rmse: 0.0353557	valid_1's rmse: 0.0767859
# RMSE accuracy: 7353.906856008195
# fold completed in 3.070693016052246s
# ** Training fold 4
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.100232	valid_1's rmse: 0.114797
# [1000]	training's rmse: 0.0441109	valid_1's rmse: 0.0791754
# [1500]	training's rmse: 0.0316836	valid_1's rmse: 0.0772826
# Early stopping, best iteration is:
# [1738]	training's rmse: 0.0276285	valid_1's rmse: 0.0769619
# RMSE accuracy: 8331.999437497583
# fold completed in 3.9822638034820557s
# ** Training fold 5
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.099815	valid_1's rmse: 0.115282
# Early stopping, best iteration is:
# [894]	training's rmse: 0.0465386	valid_1's rmse: 0.084073
# RMSE accuracy: 8344.183067489586
# fold completed in 2.210951089859009s
# CV RMSE:cv    8064.085762
# dtype: float64
# ** Training fold 1
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.0977149	valid_1's rmse: 0.116006
# [1000]	training's rmse: 0.0437098	valid_1's rmse: 0.0860868
# Early stopping, best iteration is:
# [1068]	training's rmse: 0.0420853	valid_1's rmse: 0.0859731
# RMSE accuracy: 9625.985639032999
# fold completed in 2.6298890113830566s
# ** Training fold 2
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.0979022	valid_1's rmse: 0.109897
# [1000]	training's rmse: 0.0440616	valid_1's rmse: 0.0801268
# [1500]	training's rmse: 0.0335551	valid_1's rmse: 0.0790736
# Early stopping, best iteration is:
# [1805]	training's rmse: 0.0291116	valid_1's rmse: 0.0788366
# RMSE accuracy: 8263.102557580545
# fold completed in 3.947287082672119s
# ** Training fold 3
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.0966761	valid_1's rmse: 0.123297
# [1000]	training's rmse: 0.0423548	valid_1's rmse: 0.0942833
# [1500]	training's rmse: 0.0317983	valid_1's rmse: 0.0931551
# Early stopping, best iteration is:
# [1722]	training's rmse: 0.028268	valid_1's rmse: 0.0929303
# RMSE accuracy: 10316.879021122455
# fold completed in 3.7778379917144775s
# ** Training fold 4
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.0975848	valid_1's rmse: 0.116723
# [1000]	training's rmse: 0.0441696	valid_1's rmse: 0.0818803
# [1500]	training's rmse: 0.0340619	valid_1's rmse: 0.0808366
# [2000]	training's rmse: 0.0272984	valid_1's rmse: 0.0803166
# Early stopping, best iteration is:
# [2224]	training's rmse: 0.0249451	valid_1's rmse: 0.0801558
# RMSE accuracy: 7295.253397203225
# fold completed in 4.836403131484985s
# ** Training fold 5
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.0979099	valid_1's rmse: 0.105432
# [1000]	training's rmse: 0.0447087	valid_1's rmse: 0.0755123
# [1500]	training's rmse: 0.0344901	valid_1's rmse: 0.0742486
# [2000]	training's rmse: 0.0277871	valid_1's rmse: 0.0737164
# Early stopping, best iteration is:
# [2001]	training's rmse: 0.0277775	valid_1's rmse: 0.0737117
# RMSE accuracy: 6654.866246744885
# fold completed in 4.738168001174927s
# CV RMSE:cv    8431.217372
# dtype: float64
# ** Training fold 1
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.101935	valid_1's rmse: 0.104864
# [1000]	training's rmse: 0.0453351	valid_1's rmse: 0.0645717
# [1500]	training's rmse: 0.0346781	valid_1's rmse: 0.0629325
# [2000]	training's rmse: 0.0276816	valid_1's rmse: 0.0623224
# [2500]	training's rmse: 0.0229273	valid_1's rmse: 0.062039
# [3000]	training's rmse: 0.0193555	valid_1's rmse: 0.0618338
# [3500]	training's rmse: 0.0167197	valid_1's rmse: 0.0616441
# Early stopping, best iteration is:
# [3529]	training's rmse: 0.0165961	valid_1's rmse: 0.06163
# RMSE accuracy: 9143.442188480196
# fold completed in 7.436545133590698s
# ** Training fold 2
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.101276	valid_1's rmse: 0.115243
# [1000]	training's rmse: 0.0444849	valid_1's rmse: 0.0790511
# ...
# [2500]	training's rmse: 0.0280088	valid_1's rmse: 0.100464
# [3000]	training's rmse: 0.0226735	valid_1's rmse: 0.0996567
# Early stopping, best iteration is:
# [3124]	training's rmse: 0.0216134	valid_1's rmse: 0.0995676
# RMSE accuracy: 27673.8137945512
# fold completed in 6.1695520877838135s
# ** Training fold 4
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.119229	valid_1's rmse: 0.146896
# [1000]	training's rmse: 0.0584541	valid_1's rmse: 0.114003
# [1500]	training's rmse: 0.044201	valid_1's rmse: 0.111371
# [2000]	training's rmse: 0.0349805	valid_1's rmse: 0.109911
# [2500]	training's rmse: 0.0277223	valid_1's rmse: 0.108511
# [3000]	training's rmse: 0.022282	valid_1's rmse: 0.107454
# [3500]	training's rmse: 0.0183734	valid_1's rmse: 0.10671
# [4000]	training's rmse: 0.0155087	valid_1's rmse: 0.106313
# Early stopping, best iteration is:
# [4028]	training's rmse: 0.0153708	valid_1's rmse: 0.106296
# RMSE accuracy: 55550.69176586951
# fold completed in 8.024546146392822s
# ** Training fold 5
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.118844	valid_1's rmse: 0.13568
# [1000]	training's rmse: 0.0580381	valid_1's rmse: 0.106439
# [1500]	training's rmse: 0.0432945	valid_1's rmse: 0.102853
# [2000]	training's rmse: 0.0337773	valid_1's rmse: 0.101232
# [2500]	training's rmse: 0.026905	valid_1's rmse: 0.100312
# Early stopping, best iteration is:
# [2779]	training's rmse: 0.023706	valid_1's rmse: 0.100106
# RMSE accuracy: 49721.66388933328
# fold completed in 5.654109239578247s
# CV RMSE:cv    47670.946783
# dtype: float64
# ** Training fold 1
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.121783	valid_1's rmse: 0.138491
# [1000]	training's rmse: 0.0643298	valid_1's rmse: 0.113794
# [1500]	training's rmse: 0.0513526	valid_1's rmse: 0.110911
# [2000]	training's rmse: 0.0420112	valid_1's rmse: 0.109738
# Early stopping, best iteration is:
# [2067]	training's rmse: 0.0409907	valid_1's rmse: 0.109699
# RMSE accuracy: 19475.47181087759
# fold completed in 3.4614169597625732s
# ** Training fold 2
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.120335	valid_1's rmse: 0.151796
# [1000]	training's rmse: 0.0621947	valid_1's rmse: 0.117902
# [1500]	training's rmse: 0.0478122	valid_1's rmse: 0.113512
# [2000]	training's rmse: 0.0385072	valid_1's rmse: 0.111202
# [2500]	training's rmse: 0.0315832	valid_1's rmse: 0.110466
# Early stopping, best iteration is:
# [2686]	training's rmse: 0.0296668	valid_1's rmse: 0.110365
# RMSE accuracy: 38505.3407134944
# fold completed in 4.187300205230713s
# ** Training fold 3
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.11796	valid_1's rmse: 0.16422
# [1000]	training's rmse: 0.0602799	valid_1's rmse: 0.119964
# [1500]	training's rmse: 0.0465088	valid_1's rmse: 0.117752
# [2000]	training's rmse: 0.0384574	valid_1's rmse: 0.116143
# [2500]	training's rmse: 0.0329475	valid_1's rmse: 0.115507
# [3000]	training's rmse: 0.028996	valid_1's rmse: 0.115131
# Early stopping, best iteration is:
# [2920]	training's rmse: 0.0295585	valid_1's rmse: 0.115101
# RMSE accuracy: 39453.37055314081
# fold completed in 4.813606262207031s
# ** Training fold 4
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.121495	valid_1's rmse: 0.134365
# [1000]	training's rmse: 0.063091	valid_1's rmse: 0.0998562
# [1500]	training's rmse: 0.0489138	valid_1's rmse: 0.0977106
# [2000]	training's rmse: 0.0395895	valid_1's rmse: 0.0960404
# [2500]	training's rmse: 0.0325229	valid_1's rmse: 0.0953732
# Early stopping, best iteration is:
# [2472]	training's rmse: 0.0329123	valid_1's rmse: 0.0953424
# RMSE accuracy: 19554.17475112629
# fold completed in 4.177884101867676s
# ** Training fold 5
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.120194	valid_1's rmse: 0.134553
# [1000]	training's rmse: 0.0626475	valid_1's rmse: 0.110129
# [1500]	training's rmse: 0.0489894	valid_1's rmse: 0.107045
# [2000]	training's rmse: 0.0401935	valid_1's rmse: 0.105102
# [2500]	training's rmse: 0.0334755	valid_1's rmse: 0.103432
# [3000]	training's rmse: 0.0282531	valid_1's rmse: 0.102453
# [3500]	training's rmse: 0.0243922	valid_1's rmse: 0.102109
# Early stopping, best iteration is:
# [3874]	training's rmse: 0.0218938	valid_1's rmse: 0.101895
# RMSE accuracy: 17852.14227150646
# fold completed in 6.030914068222046s
# CV RMSE:cv    26968.10002
# dtype: float64
# ** Training fold 1
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.101185	valid_1's rmse: 0.125469
# [1000]	training's rmse: 0.045016	valid_1's rmse: 0.0916901
# [1500]	training's rmse: 0.0339213	valid_1's rmse: 0.0902073
# Early stopping, best iteration is:
# [1731]	training's rmse: 0.0303391	valid_1's rmse: 0.089975
# RMSE accuracy: 9868.94982189006
# fold completed in 3.9847359657287598s
# ** Training fold 2
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.101709	valid_1's rmse: 0.110977
# Early stopping, best iteration is:
# [872]	training's rmse: 0.0488116	valid_1's rmse: 0.0816915
# RMSE accuracy: 7276.649623000533
# fold completed in 2.4139890670776367s
# ** Training fold 3
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.101118	valid_1's rmse: 0.120679
# [1000]	training's rmse: 0.0441902	valid_1's rmse: 0.0874367
# Early stopping, best iteration is:
# [1030]	training's rmse: 0.0433008	valid_1's rmse: 0.0873296
# RMSE accuracy: 9471.974118808335
# fold completed in 2.6578760147094727s
# ** Training fold 4
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.0984506	valid_1's rmse: 0.122336
# Early stopping, best iteration is:
# [819]	training's rmse: 0.0473972	valid_1's rmse: 0.101347
# RMSE accuracy: 15218.240605127829
# fold completed in 2.3251092433929443s
# ** Training fold 5
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.100806	valid_1's rmse: 0.114528
# [1000]	training's rmse: 0.04428	valid_1's rmse: 0.0821633
# [1500]	training's rmse: 0.0327296	valid_1's rmse: 0.0811058
# Early stopping, best iteration is:
# [1511]	training's rmse: 0.0325476	valid_1's rmse: 0.081065
# RMSE accuracy: 8762.840797624645
# fold completed in 3.4622421264648438s
# CV RMSE:cv    10119.730993
# dtype: float64
# ** Training fold 1
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.131489	valid_1's rmse: 0.153974
# Early stopping, best iteration is:
# [639]	training's rmse: 0.0970857	valid_1's rmse: 0.145192
# RMSE accuracy: 16081.654417535714
# fold completed in 1.265657901763916s
# ** Training fold 2
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.136746	valid_1's rmse: 0.142166
# [1000]	training's rmse: 0.0822854	valid_1's rmse: 0.112999
# Early stopping, best iteration is:
# [1170]	training's rmse: 0.0770096	valid_1's rmse: 0.112091
# RMSE accuracy: 13224.662911687406
# fold completed in 1.9884631633758545s
# ** Training fold 3
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.126564	valid_1's rmse: 0.240074
# [1000]	training's rmse: 0.0729639	valid_1's rmse: 0.208433
# Early stopping, best iteration is:
# [1237]	training's rmse: 0.0654155	valid_1's rmse: 0.207264
# RMSE accuracy: 47752.21308896904
# fold completed in 1.8741259574890137s
# ** Training fold 4
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.136398	valid_1's rmse: 0.13784
# [1000]	training's rmse: 0.0830339	valid_1's rmse: 0.108001
# [1500]	training's rmse: 0.0676139	valid_1's rmse: 0.106202
# Early stopping, best iteration is:
# [1603]	training's rmse: 0.0653215	valid_1's rmse: 0.106095
# RMSE accuracy: 13841.966318453964
# fold completed in 2.264289617538452s
# ** Training fold 5
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.135004	valid_1's rmse: 0.147722
# [1000]	training's rmse: 0.0831229	valid_1's rmse: 0.115157
# Early stopping, best iteration is:
# [956]	training's rmse: 0.0847535	valid_1's rmse: 0.115071
# RMSE accuracy: 18055.59693100867
# fold completed in 1.5694520473480225s
# CV RMSE:cv    21791.218734
# dtype: float64
# ** Training fold 1
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.102015	valid_1's rmse: 0.124134
# [1000]	training's rmse: 0.0484232	valid_1's rmse: 0.100399
# [1500]	training's rmse: 0.036366	valid_1's rmse: 0.097503
# [2000]	training's rmse: 0.0283937	valid_1's rmse: 0.0961031
# [2500]	training's rmse: 0.02274	valid_1's rmse: 0.0950443
# [3000]	training's rmse: 0.0184393	valid_1's rmse: 0.0946315
# [3500]	training's rmse: 0.0152709	valid_1's rmse: 0.0941383
# [4000]	training's rmse: 0.012797	valid_1's rmse: 0.0937358
# [4500]	training's rmse: 0.0108736	valid_1's rmse: 0.0934579
# [5000]	training's rmse: 0.00935502	valid_1's rmse: 0.0932841
# [5500]	training's rmse: 0.00817124	valid_1's rmse: 0.0930848
# [6000]	training's rmse: 0.00722843	valid_1's rmse: 0.0929751
# [6500]	training's rmse: 0.00645887	valid_1's rmse: 0.092906
# [7000]	training's rmse: 0.00583534	valid_1's rmse: 0.0928413
# Early stopping, best iteration is:
# [7145]	training's rmse: 0.00567171	valid_1's rmse: 0.0928054
# RMSE accuracy: 8480.549914443793
# fold completed in 13.575146198272705s
# ** Training fold 2
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.103657	valid_1's rmse: 0.119768
# [1000]	training's rmse: 0.0488685	valid_1's rmse: 0.0876737
# Early stopping, best iteration is:
# [1020]	training's rmse: 0.0482572	valid_1's rmse: 0.087619
# RMSE accuracy: 7453.359617245949
# fold completed in 2.3753609657287598s
# ** Training fold 3
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.103597	valid_1's rmse: 0.120705
# [1000]	training's rmse: 0.0498073	valid_1's rmse: 0.0900045
# [1500]	training's rmse: 0.0375068	valid_1's rmse: 0.0877118
# [2000]	training's rmse: 0.029263	valid_1's rmse: 0.0867336
# [2500]	training's rmse: 0.02345	valid_1's rmse: 0.0858695
# Early stopping, best iteration is:
# [2741]	training's rmse: 0.0213124	valid_1's rmse: 0.0856746
# RMSE accuracy: 7450.569410539614
# fold completed in 5.611885070800781s
# ** Training fold 4
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.103173	valid_1's rmse: 0.120254
# Early stopping, best iteration is:
# [850]	training's rmse: 0.0535424	valid_1's rmse: 0.0950606
# RMSE accuracy: 7638.356749307857
# fold completed in 2.281550168991089s
# ** Training fold 5
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.10358	valid_1's rmse: 0.127396
# [1000]	training's rmse: 0.0496225	valid_1's rmse: 0.0926067
# [1500]	training's rmse: 0.0374054	valid_1's rmse: 0.0916018
# [2000]	training's rmse: 0.0291768	valid_1's rmse: 0.0908045
# Early stopping, best iteration is:
# [1981]	training's rmse: 0.0294419	valid_1's rmse: 0.0907309
# RMSE accuracy: 9257.132235619869
# fold completed in 7.2038280963897705s
# CV RMSE:cv    8055.993585
# dtype: float64
# ** Training fold 1
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.108611	valid_1's rmse: 0.130901
# [1000]	training's rmse: 0.0520493	valid_1's rmse: 0.0966856
# [1500]	training's rmse: 0.0384362	valid_1's rmse: 0.0955155
# Early stopping, best iteration is:
# [1763]	training's rmse: 0.033571	valid_1's rmse: 0.0951159
# RMSE accuracy: 11885.085719271965
# fold completed in 4.613867998123169s
# ** Training fold 2
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.110076	valid_1's rmse: 0.121006
# [1000]	training's rmse: 0.0545587	valid_1's rmse: 0.0939999
# [1500]	training's rmse: 0.0409881	valid_1's rmse: 0.092137
# [2000]	training's rmse: 0.0319275	valid_1's rmse: 0.0915798
# Early stopping, best iteration is:
# [2356]	training's rmse: 0.0272455	valid_1's rmse: 0.0911957
# RMSE accuracy: 11354.892515044443
# fold completed in 4.825640916824341s
# ** Training fold 3
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.109763	valid_1's rmse: 0.125588
# [1000]	training's rmse: 0.0531216	valid_1's rmse: 0.0932245
# [1500]	training's rmse: 0.039164	valid_1's rmse: 0.0918408
# [2000]	training's rmse: 0.0302587	valid_1's rmse: 0.0912556
# Early stopping, best iteration is:
# [2347]	training's rmse: 0.0257669	valid_1's rmse: 0.0907622
# RMSE accuracy: 12667.104935300256
# fold completed in 4.690205097198486s
# ** Training fold 4
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.108971	valid_1's rmse: 0.123802
# [1000]	training's rmse: 0.0525706	valid_1's rmse: 0.100846
# [1500]	training's rmse: 0.039954	valid_1's rmse: 0.0994678
# Early stopping, best iteration is:
# [1748]	training's rmse: 0.03548	valid_1's rmse: 0.0992134
# RMSE accuracy: 13792.889660052668
# fold completed in 3.758805751800537s
# ** Training fold 5
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.109211	valid_1's rmse: 0.128862
# [1000]	training's rmse: 0.0529507	valid_1's rmse: 0.0925541
# Early stopping, best iteration is:
# [1256]	training's rmse: 0.0449985	valid_1's rmse: 0.0915218
# RMSE accuracy: 11200.793632413854
# fold completed in 2.9806902408599854s
# CV RMSE:cv    12180.153292
# dtype: float64
# ** Training fold 1
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.0976914	valid_1's rmse: 0.112006
# [1000]	training's rmse: 0.0416671	valid_1's rmse: 0.0777696
# [1500]	training's rmse: 0.0303368	valid_1's rmse: 0.0763572
# [2000]	training's rmse: 0.0235175	valid_1's rmse: 0.0757505
# [2500]	training's rmse: 0.0188393	valid_1's rmse: 0.0754972
# Early stopping, best iteration is:
# [2470]	training's rmse: 0.0190776	valid_1's rmse: 0.0754836
# RMSE accuracy: 6752.588555862965
# fold completed in 6.135218858718872s
# ** Training fold 2
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.0964396	valid_1's rmse: 0.113642
# [1000]	training's rmse: 0.040099	valid_1's rmse: 0.0865891
# [1500]	training's rmse: 0.0291062	valid_1's rmse: 0.0857548
# Early stopping, best iteration is:
# [1593]	training's rmse: 0.0275835	valid_1's rmse: 0.0856627
# RMSE accuracy: 10207.243503178108
# fold completed in 4.371337175369263s
# ** Training fold 3
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.097142	valid_1's rmse: 0.121449
# [1000]	training's rmse: 0.0403615	valid_1's rmse: 0.0860533
# [1500]	training's rmse: 0.0295349	valid_1's rmse: 0.0843711
# [2000]	training's rmse: 0.0226941	valid_1's rmse: 0.0839768
# [2500]	training's rmse: 0.0179533	valid_1's rmse: 0.0836947
# Early stopping, best iteration is:
# [2400]	training's rmse: 0.0187704	valid_1's rmse: 0.0836576
# RMSE accuracy: 7844.776511979556
# fold completed in 6.089062213897705s
# ** Training fold 4
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.0979253	valid_1's rmse: 0.113612
# [1000]	training's rmse: 0.042312	valid_1's rmse: 0.0810874
# [1500]	training's rmse: 0.0312845	valid_1's rmse: 0.0796844
# [2000]	training's rmse: 0.0244919	valid_1's rmse: 0.0791923
# [2500]	training's rmse: 0.0198108	valid_1's rmse: 0.0786707
# [3000]	training's rmse: 0.0163481	valid_1's rmse: 0.0783647
# [3500]	training's rmse: 0.0138087	valid_1's rmse: 0.0782261
# [4000]	training's rmse: 0.0118566	valid_1's rmse: 0.0780499
# [4500]	training's rmse: 0.0102616	valid_1's rmse: 0.0779495
# Early stopping, best iteration is:
# [4402]	training's rmse: 0.0105352	valid_1's rmse: 0.077939
# RMSE accuracy: 7570.920553476407
# fold completed in 10.453100681304932s
# ** Training fold 5
# Training until validation scores don't improve for 100 rounds.
# [500]	training's rmse: 0.0966181	valid_1's rmse: 0.110422
# [1000]	training's rmse: 0.0402231	valid_1's rmse: 0.0808807
# [1500]	training's rmse: 0.0293828	valid_1's rmse: 0.0792057
# Early stopping, best iteration is:
# [1879]	training's rmse: 0.0239716	valid_1's rmse: 0.0785156
# RMSE accuracy: 7835.463188747109
# fold completed in 5.1369407176971436s
# CV RMSE:cv    8042.198463
# dtype: float64

# %%
submission.to_csv('feat3_separate_address_type_logrent_lightgbm.csv',header=False,index=False)

# %%
print('CV mean:{}'.format(pd.DataFrame(cv_scores,index=['address_type']).mean(axis=1)[0]))
# Out:
# CV mean:17802.107504080806

# %%
pd.DataFrame(cv_scores,index=['address_type']).to_csv('CV_feat3_separate_address_type_lightgbm.csv',index=False)
