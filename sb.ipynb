# %%
import pandas as pd
import numpy as np
import json

# %%
f=open('aozora_authors.json','r')
author=json.load(f)
f.close()
author_df=pd.DataFrame(author.items())

# %%
f=open('aozora_titles.json','r')
title=json.load(f)
f.close()
title_df=pd.DataFrame(title.items())

# %%
f=open('aozora_contents.json','r')
contents=json.load(f)
f.close()
content_df=pd.DataFrame(contents.items())

# %%
f=open('train_aozora_data.json','r')
train_aozora=json.load(f)
f.close()
train_aozora_df=pd.DataFrame(train_aozora)

# %%
train_aozora_df['novels'][3]
# Out:
# [{'title_id': 'title_01847', 'content_id': 'content_08871'},
#  {'title_id': 'title_01552', 'content_id': 'content_01959'},
#  {'title_id': 'title_07805', 'content_id': 'content_10425'},
#  {'title_id': 'title_06649', 'content_id': 'content_13932'},
#  {'title_id': 'title_05975', 'content_id': 'content_10838'},
#  {'title_id': 'title_14173', 'content_id': 'content_01638'}]

# %%
f=open('train_q.json','r')
train_q=json.load(f)
f.close()
train_q_df=pd.DataFrame(train_q)

# %%
f=open('test_q.json','r')
test_q=json.load(f)
f.close()
test_q_df=pd.DataFrame(test_q)

# %%
f=open('test_aozora_data.json','r')
test_aozora=json.load(f)
f.close()
test_aozora_df=pd.DataFrame(test_aozora.items())

# %%
f=open('suggestion.json.sample','r')
suggest=json.load(f)
f.close()
suggest_df=pd.DataFrame(suggest)

# %%
train_q_df['candidates'][0]
# Out:
# ['auth_0449',
#  'auth_0255',
#  'auth_0289',
#  'auth_0581',
#  'auth_0305',
#  'auth_0094',
#  'auth_0259',
#  'auth_0604',
#  'auth_0720',
#  'auth_0007',
#  'auth_0033']

# %%
train_q_df
# Out:
#           answer                                         candidates  \
# 0      auth_0094  [auth_0449, auth_0255, auth_0289, auth_0581, a...
# 1      auth_0449  [auth_0132, auth_0597, auth_0504, auth_0449, a...
# 2      auth_0755  [auth_0070, auth_0775, auth_0785, auth_0727, a...
# 3      auth_0225  [auth_0206, auth_0461, auth_0568, auth_0172, a...
# 4      auth_0118  [auth_0807, auth_0864, auth_0806, auth_0517, a...
# 5      auth_0620  [auth_0799, auth_0301, auth_0273, auth_0189, a...
# 6      auth_0447  [auth_0789, auth_0742, auth_0182, auth_0447, a...
# 7      auth_0760  [auth_0752, auth_0861, auth_0650, auth_0684, a...
# 8      auth_0536  [auth_0632, auth_0612, auth_0446, auth_0105, a...
# 9      auth_0222  [auth_0222, auth_0134, auth_0810, auth_0120, a...
# 10     auth_0217  [auth_0100, auth_0663, auth_0169, auth_0007, a...
# 11     auth_0145  [auth_0390, auth_0145, auth_0307, auth_0007, a...
# 12     auth_0328  [auth_0347, auth_0412, auth_0305, auth_0196, a...
# ...

# %%
title_df
# Out:
#                  0                                   1
# 0      title_01492                                駅伝馬車
# 1      title_04418                           クリスマス・イーヴ
# 2      title_12565  スリーピー・ホローの伝説　故ディードリッヒ・ニッカボッカーの遺稿より
# 3      title_02816              食品の混ぜ物処理および調理の毒物（1820）
# 4      title_01902                      ファラデーの伝　電気学の泰斗
# 5      title_01847                                一片の石
# 6      title_02442                              音楽に就いて
# 7      title_01552                                  学規
# 8      title_07805                           菊の根分をしながら
# 9      title_06649                               支那の明器
# 10     title_05975                  趣味の向上　――青年学生のために――
# 11     title_13011                          少年少女におくる言葉
# 12     title_14173                                拓本の話
# 13     title_10607                               相対性理論
# 14     title_02260                                隅田の春
# 15     title_14432                                  良夜
# ...

# %%
# Out:
# set()
