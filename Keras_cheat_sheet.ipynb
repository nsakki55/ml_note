# %% [markdown]
# # Keras チートシート

# %%
import keras

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # image.load_img(img_path,target_shape=(299,299))
# ## img_pathの画像をtarget_sizeで読み込む PIL形式で返すのでmatplotlibで表示できる

# %%
from keras.preprocessing import image
import matplotlib.pyplot as plt
# %matplotlib inline
img=image.load_img('/home/nagae/Desktop/master_thesis/ILSVRC2014_val/0/ILSVRC2012_val_00003014.JPEG',target_size=(299,299))
img.show()
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7F182145C550>

# %% [markdown]
# # image.img_to_array(img)
# ## 画像ファイルnumpy配列で取得

# %%
from keras.preprocessing import image
import numpy as np
img_tensor=image.img_to_array(img)
print(type(img_tensor))
print(img_tensor.shape)

# matplotlibでも表示できる
# imagenetの画像は255で割る前処理がある
img_tensor/=255
plt.imshow(img_tensor)
plt.show()
# Out:
# <class 'numpy.ndarray'>
# (299, 299, 3)
