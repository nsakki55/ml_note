# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns
# Out:
# C:\Users\nsats\Anaconda3\envs\gpu-env\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\nsats\Anaconda3\envs\gpu-env\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\nsats\Anaconda3\envs\gpu-env\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# C:\Users\nsats\Anaconda3\envs\gpu-env\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
train=pd.read_csv('D:/bnp-paribas-cardif-claims-management/train.csv')
test=pd.read_csv('D:/bnp-paribas-cardif-claims-management/test.csv')
submission=pd.read_csv('D:/bnp-paribas-cardif-claims-management/sample_submission.csv')

# %%
train.head()
# Out:
#    ID  target        v1        v2 v3        v4         v5        v6        v7  \
# 0   3       1  1.335739  8.727474  C  3.921026   7.915266  2.599278  3.176895
# 1   4       1       NaN       NaN  C       NaN   9.191265       NaN       NaN
# 2   5       1  0.943877  5.310079  C  4.410969   5.326159  3.979592  3.928571
# 3   6       1  0.797415  8.304757  C  4.225930  11.627438  2.097700  1.987549
# 4   8       1       NaN       NaN  C       NaN        NaN       NaN       NaN
#
#          v8  ...      v122      v123      v124  v125      v126      v127  \
# 0  0.012941  ...  8.000000  1.989780  0.035754    AU  1.804126  3.113719
# 1  2.301630  ...       NaN       NaN  0.598896    AF       NaN       NaN
# 2  0.019645  ...  9.333333  2.477596  0.013452    AE  1.773709  3.922193
# 3  0.171947  ...  7.018256  1.812795  0.002267    CJ  1.415230  2.954381
# 4       NaN  ...       NaN       NaN       NaN     Z       NaN       NaN
#
#        v128  v129      v130      v131
# ...

# %%
test.head()
# Out:
#    ID            v1         v2 v3        v4       v5        v6        v7  \
# 0   0  1.375465e+00  11.361141  C  4.200778  6.57700  2.081784  1.784386
# 1   1           NaN        NaN  C       NaN      NaN       NaN       NaN
# 2   2 -4.903407e-07   8.201529  C  4.544371  6.55010  1.558442  2.467532
# 3   7  2.661870e+00   3.041241  C  1.657216  9.77308  2.078337  1.430855
# 4  10  1.252822e+00  11.283352  C  4.638388  8.52051  2.302484  3.510159
#
#          v8        v9  ...      v122      v123          v124  v125      v126  \
# 0  0.011094  9.523810  ...  7.619048  1.815241  1.112270e-07    AF  1.292368
# 1       NaN       NaN  ...       NaN       NaN           NaN     I       NaN
# 2  0.007164  7.142858  ...  5.714286  1.970928  1.412265e-02    AV  1.128724
# 3  1.252157  7.959596  ...  4.404040  8.163614  1.100329e+00     B  1.988688
# 4  0.074263  7.612904  ...  6.580644  1.325654  2.584588e-01     A  1.863796
#
#        v127      v128  v129      v130          v131
# ...

# %%
print(train.shape)
print(test.shape)
# Out:
# (114321, 133)
# (114393, 132)

# %%
dtypes_df=train.dtypes.reset_index()
dtypes_df.columns=['count','columns type']
dtypes_df.groupby('columns type').aggregate('count').reset_index()
# Out:
#   columns type  count
# 0        int64      6
# 1      float64    108
# 2       object     19

# %%
data_na=train.isnull().sum()/len(train)*100
data_na=data_na.drop(data_na[data_na==0].index).sort_values(ascending=False)
data_na[data_na>30].shape
# Out:
# (102,)

# %%
fig,ax=plt.subplots(figsize=(15,12))
plt.xticks(rotation='90')
sns.barplot(x=data_na.index,y=data_na)

# %%
import missingno as msno
msno.matrix(df=train,figsize=(20,14),color=(0,0,0.5))

# %%
train['target'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
train['target'].value_counts().plot(kind='barh',figsize=(15,5))

# %%
train['target'].value_counts()
# Out:
# 1    87021
# 0    27300
# Name: target, dtype: int64

# %%
train_id=train["ID"].unique()
test_id=test['ID'].unique()

# %%
target=train['target']

# %%
trian=train.drop(['target'],axis=1,inplace=True)

# %%
ntrain=train.shape[0]
ntest=test.shape[0]
all_data=pd.concat([train,test])

# %%
all_data.shape
# Out:
# (228714, 132)

# %%
for col in all_data.select_dtypes(include='object').columns:
    all_data[col].value_counts().plot(kind='barh',figsize=(15,5))
    plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
cols=all_data.select_dtypes(include='object').columns

for col in cols:
    all_data[col].fillna('NaN')
    le=LabelEncoder()
    le.fit(all_data[col].astype(str).values)
    all_data[col]=le.transform(all_data[col])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\gpu-env\lib\site-packages\sklearn\preprocessing\label.py in _encode_python(values, uniques, encode)
#      63         try:
# ---> 64             encoded = np.array([table[v] for v in values])
#      65         except KeyError as e:
#
# ~\Anaconda3\envs\gpu-env\lib\site-packages\sklearn\preprocessing\label.py in <listcomp>(.0)
#      63         try:
# ---> 64             encoded = np.array([table[v] for v in values])
#      65         except KeyError as e:
#
# KeyError: nan
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-111-1ba277e9cc97> in <module>
#       7     le=LabelEncoder()
#       8     le.fit(all_data[col].astype(str).values)
# ----> 9     all_data[col]=le.transform(all_data[col])
# ...

# %%
all_data.select_dtypes(include='object')
# Out:
#          v3   v22 v24  v30  v31 v47 v52  v56 v66 v71 v74 v75 v79 v91 v107  \
# 0         C   XDX   C    C    A   C   G   DI   C   F   B   D   E   A    E
# 1         C   GUV   C    C    A   E   G   DY   A   F   B   D   D   B    B
# 2         C    FQ   E  NaN    A   C   F   AS   A   B   B   B   E   G    C
# 3         C  ACUE   D    C    B   C   H   BW   A   F   B   D   B   B    B
# 4         C   HIT   E  NaN    A   I   H  NaN   C   F   B   D   C   G    C
# 5         C   AYX   A  NaN    A   I   K   DX   A   F   B   D   I   G    C
# 6         C   NFD   E    G    A   C   A   AS   A   F   B   D   E   B    B
# 7         C  AHBW   D    C    A   I   C   DP   C   F   B   D   C   A    E
# 8       NaN   GKQ   E  NaN  NaN   D   H   AF   B   B   B   B   P   C    D
# 9         C   PYF   C    C    A   I   A  NaN   A   F   B   D   C   A    E
# 10        C   GEH   E    D    A   I   E   CY   A   F   B   D   C   F    A
# 11        C  ABQS   D    G    A   C   A   AW   C   F   B   D   E   A    E
# ...
