# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from collections import defaultdict
pd.set_option('display.max_columns', 50)

# %%
train = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')
kiji = pd.read_csv('../input/kiji_metadata.csv')
submission = pd.read_csv('../input/sample_submission.csv')

# %%
def datetime_feature(df):
    df['ts'] = pd.to_datetime(df['ts'])
    month = df['ts'].dt.month
    day = df['ts'].dt.day
    hour = df['ts'].dt.hour
    return month, day, hour
train['ts_month'], train['ts_day'], train['ts_hour'] = datetime_feature(train)

# %%
def drop_many_null_columns(df):
# Out:
#                              kiji_id ig_ctx_product er_geo_pref_j_name  \
# 0       DGXMZO5058268004102019000000         DS-App                NaN
# 1       DGXMZO5058271004102019000000         DS-App                NaN
# 2       DGXMZO5058239004102019000000         DS-App                NaN
# 3       DGXMZO5058249004102019000000         DS-App                NaN
# 4       DGXMZO5058255004102019000000         DS-App                NaN
# ...                              ...            ...                ...
# 477052  DGXMZO5006642020092019000000         DS-App                和歌山
# 477053  DGXMZO5061272004102019PE1000         DS-App                和歌山
# 477054  DGXMZO5077023008102019UU8000         DS-App                和歌山
# 477055  DGXLSSXK20159_08102019000000         DS-App                和歌山
# 477056  DGXMZO5085136010102019000000         DS-App                和歌山
#
#        er_geo_city_j_name er_geo_country_code er_dev_browser_family  \
# 0                     NaN                 NaN                   NaN
# 1                     NaN                 NaN                   NaN
# 2                     NaN                 NaN                   NaN
# 3                     NaN                 NaN                   NaN
# 4                     NaN                 NaN                   NaN
# ...                   ...                 ...                   ...
# 477052               和歌山市                  JP                   NaN
# 477053               和歌山市                  JP                   NaN
# 477054               和歌山市                  JP                   NaN
# 477055               和歌山市                  JP                   NaN
# 477056               和歌山市                  JP                   NaN
#
#        er_dev_browser_version er_dev_device_name er_dev_device_type  \
# 0                         NaN             SO-01H                 PC
# 1                         NaN             SO-01H                 PC
# 2                         NaN             SO-01H                 PC
# 3                         NaN             SO-01H                 PC
# 4                         NaN             SO-01H                 PC
# ...                       ...                ...                ...
# 477052                    NaN             iPhone             Mobile
# 477053                    NaN             iPhone             Mobile
# 477054                    NaN             iPhone             Mobile
# 477055                    NaN             iPhone             Mobile
# 477056                    NaN             iPhone             Mobile
#
#        er_dev_manufacture er_dev_os_family er_dev_os_version  \
# 0                     NaN          Android               7.0
# 1                     NaN          Android               7.0
# 2                     NaN          Android               7.0
# 3                     NaN          Android               7.0
# 4                     NaN          Android               7.0
# ...                   ...              ...               ...
# 477052              Apple              iOS            13.1.2
# 477053              Apple              iOS            13.1.2
# 477054              Apple              iOS            13.1.2
# 477055              Apple              iOS            13.1.2
# 477056              Apple              iOS            13.1.2
#
#        er_rfs_reffered_visit er_rfs_service_name er_rfs_service_type  \
# 0                       True                 NaN                 NaN
# 1                       True                 NaN                 NaN
# 2                       True                 NaN                 NaN
# 3                       True                 NaN                 NaN
# 4                       True                 NaN                 NaN
# ...                      ...                 ...                 ...
# 477052                  True                 NaN                 NaN
# 477053                  True                 NaN                 NaN
# 477054                  True                 NaN                 NaN
# 477055                  True                 NaN                 NaN
# 477056                  True                 NaN                 NaN
#
#                   er_rfc_kiji_id_raw ig_usr_connection
# 0                                NaN               LTE
# 1       DGXMZO5058268004102019000000               LTE
# 2       DGXMZO5058271004102019000000               LTE
# 3       DGXMZO5058239004102019000000               LTE
# 4       DGXMZO5058249004102019000000               LTE
# ...                              ...               ...
# 477052                           NaN              WiFi
# 477053                           NaN              WiFi
# 477054                           NaN              WiFi
# 477055                           NaN              WiFi
# 477056                           NaN              WiFi
#
# [477057 rows x 17 columns]

# %%
train.isnull().sum() * 100  > 90
